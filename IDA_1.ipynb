# %%
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn import tree
import matplotlib.pyplot as plt 
import xlsxwriter

def tree_generation_1(f_name):
    accuracy=[]
    precision=[]
    recall=[]
    min_datasets=[3,8,12,30,50]


    # reading the data using read_csv function of the pandas library which directly reads the csv file and creates a datagram of the same  
    data = pd.read_csv(f_name) 
    
    
    # dividing the data into two sets , ie X denotes all the attributes data and Y denotes the class output data which is to be predicted 
    X = data.values[:, 0:6]      #1st to 6th column
    Y = data.values[:,6]         #last column 

    
    # dividing the records into testing and training data using train_test_split function, which takes percentage as input for test size
    # hence 310 given samples , 210 to be used as test_size so it is 67.77%
    X_train, X_test, y_train, y_test = train_test_split( X, Y, train_size = 0.678, random_state = 100)



    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 3
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=3)
    dt_gini.fit(X_train, y_train)


    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(3,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)


    #exporting the created decision tree to pdf 
    with open("biomechanical_dt_gini_3.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "biomechanical_dt_gini_3.dot" -o "biomechanical_dt_gini_3.pdf"


    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 8
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=8)
    dt_gini.fit(X_train, y_train)


    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    
    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(8,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)

    
    #exporting the created decision tree to pdf 
    with open("biomechanical_dt_gini_8.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "biomechanical_dt_gini_8.dot" -o "biomechanical_dt_gini_8.pdf"


    
    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 12
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=12)
    dt_gini.fit(X_train, y_train)



    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    
    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(12,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)

    
    #exporting the created decision tree to pdf 
    with open("biomechanical_dt_gini_12.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "biomechanical_dt_gini_12.dot" -o "biomechanical_dt_gini_12.pdf"


    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 30
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=30)
    dt_gini.fit(X_train, y_train)


    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(30,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)

    #exporting the created decision tree to pdf 
    with open("biomechanical_dt_gini_30.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "biomechanical_dt_gini_30.dot" -o "biomechanical_dt_gini_30.pdf"


    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 50
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=50)
    dt_gini.fit(X_train, y_train)



    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(50,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)

    #exporting the created decision tree to pdf 
    with open("biomechanical_dt_gini_50.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "biomechanical_dt_gini_50.dot" -o "biomechanical_dt_gini_50.pdf"


    #plotting graphs
    fig1 = plt.figure(1)
    plt.plot(min_datasets,accuracy,label="accuracy")
    plt.plot(min_datasets,precision,label="precision")
    plt.plot(min_datasets,recall,label="recall")
    plt.grid(True)
    plt.legend(['accuracy', 'precision', 'recall'], loc='upper right')
    fig1.savefig('plot_1.png')
    plt.close()
    # add plt.close() after you've saved the figure
    #plt.show()
     
        
    fig2 = plt.figure(2)
    plt.plot(precision,recall)
    fig2.savefig('precision_recall_1.png')
    plt.close()
    print('\n ############################################################################################# \n')

def tree_generation_2(f_name):
    accuracy=[]
    precision=[]
    recall=[]
    min_datasets=[3,8,12,30,50]


    # reading the data using read_csv function of the pandas library which directly reads the csv file and creates a datagram of the same  
    data = pd.read_csv(f_name) 


    # dividing the data into two sets , ie X denotes all the attributes data and Y denotes the class output data which is to be predicted 
    X = data.values[:, 0:6]      #1st to 6th column
    Y = data.values[:,6]         #last column 

    # dividing the records into testing and training data using train_test_split function, which takes percentage as input for test size
    # hence 310 given samples , 210 to be used as test_size so it is 67.77%
    X_train, X_test, y_train, y_test = train_test_split( X, Y, train_size = 0.678, random_state = 100)



    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 3
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=3)
    dt_gini.fit(X_train, y_train)


    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(3,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)


    #exporting the created decision tree to pdf 
    with open("class_3_biomechanical_dt_gini_3.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "class_3_biomechanical_dt_gini_3.dot" -o "class_3_biomechanical_dt_gini_3.pdf"


    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 8
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=8)
    dt_gini.fit(X_train, y_train)


    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(8,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)

    #exporting the created decision tree to pdf 
    with open("class_3_biomechanical_dt_gini_8.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "class_3_biomechanical_dt_gini_8.dot" -o "class_3_biomechanical_dt_gini_8.pdf"


    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 12
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=12)
    dt_gini.fit(X_train, y_train)


    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(12,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)
    
    
    #exporting the created decision tree to pdf 
    with open("class_3_biomechanical_dt_gini_12.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "class_3_biomechanical_dt_gini_12.dot" -o "class_3_biomechanical_dt_gini_12.pdf"


    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 30
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=30)
    dt_gini.fit(X_train, y_train)


    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(30,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)

    #exporting the created decision tree to pdf 
    with open("class_3_biomechanical_dt_gini_30.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "class_3_biomechanical_dt_gini_30.dot" -o "class_3_biomechanical_dt_gini_30.pdf"
    
    
    
    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 50
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=50)
    dt_gini.fit(X_train, y_train)



    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(50,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)


    #exporting the created decision tree to pdf 
    with open("class_3_biomechanical_dt_gini_50.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "class_3_biomechanical_dt_gini_50.dot" -o "class_3_biomechanical_dt_gini_50.pdf"


    #plotting graphs
    fig1 = plt.figure(1)
    plt.plot(min_datasets,accuracy,label="accuracy")
    plt.plot(min_datasets,precision,label="precision")
    plt.plot(min_datasets,recall,label="recall")
    plt.grid(True)
    plt.legend(['accuracy', 'precision', 'recall'], loc='upper right')
    fig1.savefig('plot_2.png')
    plt.close()
    # add plt.close() after you've saved the figure
    #plt.show()
    
    
    fig2 = plt.figure(2)
    plt.plot(precision,recall)
    fig2.savefig('precision_recall_2.png')
    plt.close()
    print('\n ############################################################################################# \n')
def tree_generation_3(f_name):
    df = pd.read_csv(f_name) 
    revised_dataframe = pd.DataFrame()
    bin_boundary=[]
    columns=df.columns
    y=0
    for col in columns[0:6]:
        hist, bin_edges = np.histogram(df[col][1:], bins=4)
        bin_boundary.append(bin_edges)
        col_trans_output=pd.DataFrame(pd.cut(df[col],4,labels=range(4)))
        revised_dataframe = pd.concat([revised_dataframe,col_trans_output], axis=1)
        
    
    #writer = pd.ExcelWriter('test.xlsx',engine='xlsxwriter')   
    #workbook=writer.book
    #revised_dataframe.to_excel(writer,sheet_name='Validation1',startrow=0 , startcol=0) 
    #workbook.close() 


    for x in bin_boundary:
        print('Boundaries for {} are {} \n'.format(columns[y],x))
        y=y+1
    print('\n ############################################################################################# \n')    
    accuracy=[]
    precision=[]
    recall=[]
    min_datasets=[3,8,12,30,50]


    # reading the data using read_csv function of the pandas library which directly reads the csv file and creates a datagram of the same  
    data = pd.read_csv(f_name) 
    
    
    # dividing the data into two sets , ie X denotes all the attributes data and Y denotes the class output data which is to be predicted 
    X = data.values[:, 0:6]      #1st to 6th column
    Y = data.values[:,6]         #last column 

    
    # dividing the records into testing and training data using train_test_split function, which takes percentage as input for test size
    # hence 310 given samples , 210 to be used as test_size so it is 67.77%
    X_train, X_test, y_train, y_test = train_test_split( X, Y, train_size = 0.678, random_state = 100)



    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 3
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=3)
    dt_gini.fit(X_train, y_train)


    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(3,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)


    #exporting the created decision tree to pdf 
    with open("revised_biomechanical_dt_gini_3.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "revised_biomechanical_dt_gini_3.dot" -o "revised_biomechanical_dt_gini_3.pdf"


    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 8
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=8)
    dt_gini.fit(X_train, y_train)


    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    
    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(8,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)

    
    #exporting the created decision tree to pdf 
    with open("revised_biomechanical_dt_gini_8.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "revised_biomechanical_dt_gini_8.dot" -o "revised_biomechanical_dt_gini_8.pdf"


    
    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 12
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=12)
    dt_gini.fit(X_train, y_train)



    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    
    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(12,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)
    
    
    #exporting the created decision tree to pdf 
    with open("revised_biomechanical_dt_gini_12.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "revised_biomechanical_dt_gini_12.dot" -o "revised_biomechanical_dt_gini_12.pdf"


    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 30
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=30)
    dt_gini.fit(X_train, y_train)


    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(30,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)

    #exporting the created decision tree to pdf 
    with open("revised_biomechanical_dt_gini_30.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "revised_biomechanical_dt_gini_30.dot" -o "revised_biomechanical_dt_gini_30.pdf"
    
    
    
    #creating the classifier using DecisionTreeClassifier fucntion with Gini index approach and minimum records per leaf node as 50
    dt_gini = DecisionTreeClassifier(criterion = "gini",min_samples_leaf=50)
    dt_gini.fit(X_train, y_train)



    #predicting the class values by testing the model with testing dataset and storing them
    y_pred_gini = dt_gini.predict(X_test)

    #calculating the accuracy, precision and recal and storing them 
    a = accuracy_score(y_test,y_pred_gini)
    b = precision_score(y_test, y_pred_gini,average='macro')
    c = recall_score(y_test, y_pred_gini,average='macro')
    print("Accuracy,Precision,Recall for gini Dt with {} data sets at leaf node are {},{},{}".format(50,a,b,c))
    accuracy.append(a)
    precision.append(b)
    recall.append(c)


    #exporting the created decision tree to pdf 
    with open("revised_biomechanical_dt_gini_50.dot", "w") as f:
     f = tree.export_graphviz(dt_gini, out_file=f,feature_names=data.columns.values[0:6])
    # !dot -Tpdf "revised_biomechanical_dt_gini_50.dot" -o "revised_biomechanical_dt_gini_50.pdf"


    #plotting graphs
    fig1 = plt.figure(1)
    plt.plot(min_datasets,accuracy,label="accuracy")
    plt.plot(min_datasets,precision,label="precision")
    plt.plot(min_datasets,recall,label="recall")
    plt.grid(True)
    plt.legend(['accuracy', 'precision', 'recall'], loc='upper right')
    fig1.savefig('plot_class_3.png')
    plt.close()
    # add plt.close() after you've saved the figure
    #plt.show()
    
    
    fig2 = plt.figure(2)
    plt.plot(precision,recall)
    fig2.savefig('precision_accuracy_3.png')
    plt.close()
tree_generation_1("Biomechanical_Data_column_2C_weka.csv")
tree_generation_2("BiomechanicalData_column_3C_weka.csv")
tree_generation_3("Biomechanical_Data_column_2C_weka.csv")
# Out:
# Accuracy,Precision,Recall for gini Dt with 3 data sets at leaf node are 0.77,0.7473958333333333,0.7505494505494505
# Accuracy,Precision,Recall for gini Dt with 8 data sets at leaf node are 0.78,0.7606358111266948,0.7450549450549451
# Accuracy,Precision,Recall for gini Dt with 12 data sets at leaf node are 0.79,0.7738095238095237,0.7527472527472527
# Accuracy,Precision,Recall for gini Dt with 30 data sets at leaf node are 0.73,0.7083333333333333,0.7197802197802198
# Accuracy,Precision,Recall for gini Dt with 50 data sets at leaf node are 0.7,0.6671341748480599,0.6571428571428571
#
#  #############################################################################################
#
# Accuracy,Precision,Recall for gini Dt with 3 data sets at leaf node are 0.77,0.7291666666666666,0.7431295630380298
# Accuracy,Precision,Recall for gini Dt with 8 data sets at leaf node are 0.78,0.7432557225660674,0.7549308052740548
# ...
